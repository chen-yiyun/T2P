# %%
# 读取3dpw里的一个.pt文件(preprocessed\3dpw_input10_v2\train\0.pt),并将读取到的TemporalData对象转化为字典
import torch
import os.path as osp

# 指定文件路径
pt_path = osp.join('preprocessed', '3dpw_input10_v2', 'train', '0.pt')

# 读取.pt文件
data = torch.load(pt_path)

# 将TemporalData对象转换为字典
data_dict = dict(data)

# 打印字典中的所有键
print("数据字典中包含的键:")
print(data_dict.keys())
for key in data_dict.keys():
    print(key)

# 打印一些关键数据的形状
print("\n数据形状信息:")
print(f"body_xyz: {data_dict['body_xyz']}")  # 人体关节点坐标
# print(f"x: {data_dict['x'].shape}")  # 输入序列
# print(f"positions: {data_dict['positions'].shape}")  # 位置序列
# print(f"y: {data_dict['y'].shape}")  # 输出序列
# print(f"num_nodes: {data_dict['num_nodes']}")  # 节点数量
body_xyz_one_f_t = data_dict["body_xyz"][0][0]
# 可视化
# Out:
# 数据字典中包含的键:
# dict_keys(['x', 'edge_index', 'bos_mask', 'body_xyz', 'rotate_mat', 'rotate_angles', 'positions', 'y', 'num_nodes', 'padding_mask'])
# x
# edge_index
# bos_mask
# body_xyz
# rotate_mat
# rotate_angles
# positions
# y
# num_nodes
# padding_mask
#
# 数据形状信息:
# body_xyz: tensor([[[[ 2.1083e+00, -1.2357e+00,  7.2276e-01],
#           [ 2.1461e+00, -1.3555e+00,  7.1819e-01],
#           [ 2.0793e+00, -1.2121e+00,  3.2018e-01],
#           ...,
#           [ 2.1932e+00, -1.4978e+00,  9.8199e-01],
#           [ 1.9755e+00, -1.1066e+00,  6.9107e-01],
#           [ 2.2266e+00, -1.5102e+00,  7.0396e-01]],
#
#          [[ 2.1477e+00, -1.2369e+00,  6.9795e-01],
#           [ 2.1870e+00, -1.3562e+00,  6.9365e-01],
#           [ 2.1210e+00, -1.2128e+00,  2.9524e-01],
#           ...,
#           [ 2.2317e+00, -1.4994e+00,  9.5860e-01],
#           [ 2.0163e+00, -1.1084e+00,  6.6685e-01],
#           [ 2.2677e+00, -1.5075e+00,  6.8072e-01]],
#
#          [[ 2.1856e+00, -1.2386e+00,  6.7350e-01],
#           [ 2.2281e+00, -1.3568e+00,  6.6921e-01],
#           [ 2.1631e+00, -1.2122e+00,  2.7067e-01],
#           ...,
#           [ 2.2732e+00, -1.5007e+00,  9.3568e-01],
#           [ 2.0556e+00, -1.1111e+00,  6.4542e-01],
#           [ 2.3119e+00, -1.5034e+00,  6.5808e-01]],
#
#          ...,
#
#          [[ 2.0882e+00, -1.3481e+00,  2.7579e-01],
#           [ 2.1675e+00, -1.2506e+00,  2.8017e-01],
#           [ 2.0356e+00, -1.3187e+00, -1.2400e-01],
#           ...,
#           [ 2.2917e+00, -1.0966e+00,  5.9067e-01],
#           [ 1.8518e+00, -1.4864e+00,  2.4200e-01],
#           [ 2.2618e+00, -1.0139e+00,  3.2453e-01]],
#
#          [[ 2.0376e+00, -1.3299e+00,  2.6582e-01],
#           [ 2.1069e+00, -1.2251e+00,  2.6888e-01],
#           [ 2.0213e+00, -1.3290e+00, -1.3816e-01],
#           ...,
#           [ 2.2319e+00, -1.0719e+00,  5.8472e-01],
#           [ 1.7428e+00, -1.4400e+00,  2.3994e-01],
#           [ 2.1859e+00, -9.8459e-01,  3.2234e-01]],
#
#          [[ 1.9853e+00, -1.3070e+00,  2.4617e-01],
#           [ 2.0443e+00, -1.1960e+00,  2.4877e-01],
#           [ 1.9941e+00, -1.3264e+00, -1.5758e-01],
#           ...,
#           [ 2.1689e+00, -1.0431e+00,  5.6133e-01],
#           [ 1.6394e+00, -1.3903e+00,  2.3316e-01],
#           [ 2.1143e+00, -9.5580e-01,  3.0061e-01]]],
#
#
#         [[[ 2.3768e+00, -2.8838e-01,  6.0593e-01],
#           [ 2.3494e+00, -4.0089e-01,  5.9928e-01],
#           [ 2.4692e+00, -2.5789e-01,  2.3420e-01],
#           ...,
#           [ 2.2830e+00, -5.3089e-01,  8.6034e-01],
#           [ 2.5618e+00, -1.7379e-01,  6.4241e-01],
#           [ 2.3949e+00, -5.4006e-01,  6.2989e-01]],
#
#          [[ 2.4315e+00, -2.8429e-01,  5.8405e-01],
#           [ 2.3928e+00, -3.9348e-01,  5.7816e-01],
#           [ 2.5735e+00, -2.7181e-01,  2.2719e-01],
#           ...,
#           [ 2.3244e+00, -5.1282e-01,  8.3812e-01],
#           [ 2.6336e+00, -1.7866e-01,  6.2192e-01],
#           [ 2.4413e+00, -5.3128e-01,  6.1073e-01]],
#
#          [[ 2.4947e+00, -2.8024e-01,  5.6391e-01],
#           [ 2.4398e+00, -3.8230e-01,  5.5897e-01],
#           [ 2.6472e+00, -2.8135e-01,  2.1120e-01],
#           ...,
#           [ 2.3596e+00, -4.8612e-01,  8.2029e-01],
#           [ 2.7102e+00, -1.8142e-01,  6.0171e-01],
#           [ 2.4734e+00, -5.1912e-01,  5.9297e-01]],
#
#          ...,
#
#          [[ 2.4141e+00, -1.3443e-01,  1.9640e-02],
#           [ 2.4280e+00, -2.0582e-02,  2.4597e-03],
#           [ 2.0726e+00, -1.0487e-01, -1.5403e-01],
#           ...,
#           [ 2.4174e+00,  1.8821e-01,  2.4894e-01],
#           [ 2.2863e+00, -3.1738e-01,  1.4020e-02],
#           [ 2.3658e+00,  1.5957e-01, -5.1304e-04]],
#
#          [[ 2.3575e+00, -1.4020e-01,  1.5396e-03],
#           [ 2.3794e+00, -2.7532e-02, -1.4990e-02],
#           [ 2.0445e+00, -8.6318e-02, -2.1481e-01],
#           ...,
#           [ 2.3610e+00,  1.8213e-01,  2.2995e-01],
#           [ 2.2176e+00, -2.9668e-01, -2.0924e-02],
#           [ 2.3214e+00,  1.5269e-01, -2.1595e-02]],
#
#          [[ 2.2995e+00, -1.4342e-01, -1.0729e-02],
#           [ 2.3270e+00, -3.1579e-02, -2.4364e-02],
#           [ 1.9956e+00, -7.6932e-02, -2.3636e-01],
#           ...,
#           [ 2.2965e+00,  1.7458e-01,  2.1651e-01],
#           [ 2.1463e+00, -2.7389e-01, -4.9588e-02],
#           [ 2.2720e+00,  1.4686e-01, -3.7149e-02]]]])
